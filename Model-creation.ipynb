# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# Preprocessing the Training set
train_data = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_data.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Preprocessing the Testing set
test_data = ImageDataGenerator(rescale = 1./255)
test_set = test_data.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Creating model
model = Sequential()

# Adding 1st convo layer
model.add(Conv2D(filters=32, 
                kernel_size=3,
                activation='relu',
                input_shape=[64, 64, 3]))

# Adding 1st Pooling layer
model.add(MaxPooling2D(pool_size=2,
                       strides=2))

# Adding 2nd convo layer
model.add(Conv2D(filters=64, 
                kernel_size=3,
                activation='relu',
                ))

# Adding 2nd Pooling layer
model.add(MaxPooling2D(pool_size=2,
                       strides=2))

# Adding Flattening layer
model.add(Flatten())

# creating Dence layer
model.add(Dense(units=128,
                activation='relu'))

# Adding outout layer
model.add(Dense(units=1,
                activation='sigmoid'))

# Compiling model
model.compile(optimizer="adam",
              loss='binary_crossentropy',
              metrics='accuracy')

# Training Data
model.fit(x=training_set, validation_data=test_set, epochs=100)

# Saving Model
model.save("BT_MODEL-v1.h5")
print("Model Successfully created..")
# Out:
# Found 195 images belonging to 2 classes.
# Found 58 images belonging to 2 classes.
# Epoch 1/100
# 7/7 [==============================] - 2s 226ms/step - loss: 1.2996 - accuracy: 0.4774 - val_loss: 0.7378 - val_accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 1s 130ms/step - loss: 0.6012 - accuracy: 0.6615 - val_loss: 0.6449 - val_accuracy: 0.5345
# Epoch 3/100
# 7/7 [==============================] - 1s 162ms/step - loss: 0.5726 - accuracy: 0.7070 - val_loss: 0.6504 - val_accuracy: 0.5690
# Epoch 4/100
# 7/7 [==============================] - 1s 149ms/step - loss: 0.5931 - accuracy: 0.7082 - val_loss: 0.6443 - val_accuracy: 0.6034
# Epoch 5/100
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5723 - accuracy: 0.6933 - val_loss: 0.5885 - val_accuracy: 0.7759
# Epoch 6/100
# 7/7 [==============================] - 1s 153ms/step - loss: 0.5431 - accuracy: 0.6851 - val_loss: 0.5907 - val_accuracy: 0.7586
# Epoch 7/100
# 7/7 [==============================] - 1s 150ms/step - loss: 0.5551 - accuracy: 0.7415 - val_loss: 0.6056 - val_accuracy: 0.7414
# Epoch 8/100
# 7/7 [==============================] - 1s 131ms/step - loss: 0.5364 - accuracy: 0.7289 - val_loss: 0.5988 - val_accuracy: 0.7586
# Epoch 9/100
# 7/7 [==============================] - 1s 142ms/step - loss: 0.5739 - accuracy: 0.7120 - val_loss: 0.5416 - val_accuracy: 0.7931
# Epoch 10/100
# Epoch 47/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.2745 - accuracy: 0.8824 - val_loss: 0.5836 - val_accuracy: 0.7414
# Epoch 48/100
# 7/7 [==============================] - 1s 190ms/step - loss: 0.2202 - accuracy: 0.9347 - val_loss: 0.6162 - val_accuracy: 0.7414
# Epoch 49/100
# 7/7 [==============================] - 1s 172ms/step - loss: 0.2933 - accuracy: 0.8962 - val_loss: 0.5284 - val_accuracy: 0.7931
# Epoch 50/100
# 7/7 [==============================] - 1s 181ms/step - loss: 0.2605 - accuracy: 0.8867 - val_loss: 0.7515 - val_accuracy: 0.7069
# Epoch 51/100
# 7/7 [==============================] - 1s 166ms/step - loss: 0.2588 - accuracy: 0.8922 - val_loss: 0.6095 - val_accuracy: 0.7586
# Epoch 52/100
# 7/7 [==============================] - 1s 169ms/step - loss: 0.2617 - accuracy: 0.9223 - val_loss: 0.5985 - val_accuracy: 0.7241
# Epoch 53/100
# 7/7 [==============================] - 1s 176ms/step - loss: 0.2379 - accuracy: 0.8875 - val_loss: 0.6213 - val_accuracy: 0.7241
# Epoch 54/100
# 7/7 [==============================] - 1s 182ms/step - loss: 0.3550 - accuracy: 0.8735 - val_loss: 0.6232 - val_accuracy: 0.6897
# Epoch 55/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.2353 - accuracy: 0.9094 - val_loss: 0.6477 - val_accuracy: 0.6897
# Epoch 56/100
# 7/7 [==============================] - 1s 187ms/step - loss: 0.2067 - accuracy: 0.9394 - val_loss: 0.7075 - val_accuracy: 0.7069
# Epoch 57/100
# 7/7 [==============================] - 1s 157ms/step - loss: 0.1916 - accuracy: 0.9006 - val_loss: 0.6877 - val_accuracy: 0.7241
# Epoch 58/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.2597 - accuracy: 0.8695 - val_loss: 0.6017 - val_accuracy: 0.7414
# Epoch 59/100
# 7/7 [==============================] - 1s 176ms/step - loss: 0.1660 - accuracy: 0.9599 - val_loss: 0.5985 - val_accuracy: 0.7586
# Epoch 60/100
# 7/7 [==============================] - 1s 154ms/step - loss: 0.1943 - accuracy: 0.9188 - val_loss: 0.6271 - val_accuracy: 0.7931
# Epoch 61/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.1846 - accuracy: 0.9129 - val_loss: 0.6203 - val_accuracy: 0.8276
# Epoch 62/100
# 7/7 [==============================] - 1s 178ms/step - loss: 0.2275 - accuracy: 0.9029 - val_loss: 0.6971 - val_accuracy: 0.7931
# Epoch 63/100
# 7/7 [==============================] - 1s 169ms/step - loss: 0.2690 - accuracy: 0.8680 - val_loss: 0.4951 - val_accuracy: 0.8103
# Epoch 64/100
# 7/7 [==============================] - 1s 156ms/step - loss: 0.2971 - accuracy: 0.8761 - val_loss: 0.5306 - val_accuracy: 0.8103
# Epoch 65/100
# 7/7 [==============================] - 1s 149ms/step - loss: 0.2278 - accuracy: 0.9132 - val_loss: 0.5224 - val_accuracy: 0.7759
# Epoch 66/100
# 7/7 [==============================] - 1s 158ms/step - loss: 0.2291 - accuracy: 0.8793 - val_loss: 0.6652 - val_accuracy: 0.6897
# Epoch 67/100
# 7/7 [==============================] - 1s 155ms/step - loss: 0.2312 - accuracy: 0.9326 - val_loss: 0.5433 - val_accuracy: 0.8103
# Epoch 68/100
# 7/7 [==============================] - 1s 162ms/step - loss: 0.1790 - accuracy: 0.9187 - val_loss: 0.5327 - val_accuracy: 0.8103
# Epoch 69/100
# 7/7 [==============================] - 1s 164ms/step - loss: 0.1611 - accuracy: 0.9272 - val_loss: 0.6291 - val_accuracy: 0.7586
# Epoch 70/100
# 7/7 [==============================] - 1s 186ms/step - loss: 0.1410 - accuracy: 0.9503 - val_loss: 0.6091 - val_accuracy: 0.7931
# Epoch 71/100
# 7/7 [==============================] - 1s 175ms/step - loss: 0.1542 - accuracy: 0.9438 - val_loss: 0.5399 - val_accuracy: 0.8103
# Epoch 72/100
# 7/7 [==============================] - 1s 171ms/step - loss: 0.1408 - accuracy: 0.9597 - val_loss: 0.5286 - val_accuracy: 0.8103
# Epoch 73/100
# 7/7 [==============================] - 1s 161ms/step - loss: 0.1417 - accuracy: 0.9426 - val_loss: 0.5276 - val_accuracy: 0.8103
# Epoch 74/100
# 7/7 [==============================] - 1s 193ms/step - loss: 0.2927 - accuracy: 0.8877 - val_loss: 0.8861 - val_accuracy: 0.6724
# Epoch 75/100
# 7/7 [==============================] - 1s 165ms/step - loss: 0.1842 - accuracy: 0.9146 - val_loss: 0.8067 - val_accuracy: 0.7069
# Epoch 76/100
# 7/7 [==============================] - 1s 173ms/step - loss: 0.1438 - accuracy: 0.9518 - val_loss: 0.6911 - val_accuracy: 0.7069
# Epoch 77/100
# 7/7 [==============================] - 1s 165ms/step - loss: 0.1675 - accuracy: 0.9342 - val_loss: 0.6437 - val_accuracy: 0.7586
# Epoch 78/100
# 7/7 [==============================] - 1s 174ms/step - loss: 0.1733 - accuracy: 0.9247 - val_loss: 0.6726 - val_accuracy: 0.7931
# Epoch 79/100
# 7/7 [==============================] - 1s 162ms/step - loss: 0.1223 - accuracy: 0.9570 - val_loss: 0.6939 - val_accuracy: 0.8103
# Epoch 80/100
# 7/7 [==============================] - 1s 158ms/step - loss: 0.1225 - accuracy: 0.9459 - val_loss: 0.9045 - val_accuracy: 0.6897
# Epoch 81/100
# 7/7 [==============================] - 1s 162ms/step - loss: 0.1739 - accuracy: 0.9244 - val_loss: 0.7470 - val_accuracy: 0.7586
# Epoch 82/100
# 7/7 [==============================] - 1s 177ms/step - loss: 0.2280 - accuracy: 0.9203 - val_loss: 0.8868 - val_accuracy: 0.7069
# Epoch 83/100
# 7/7 [==============================] - 1s 159ms/step - loss: 0.2185 - accuracy: 0.9065 - val_loss: 0.6654 - val_accuracy: 0.7241
# Epoch 84/100
# 7/7 [==============================] - 1s 173ms/step - loss: 0.1589 - accuracy: 0.9523 - val_loss: 0.7846 - val_accuracy: 0.7069
# Epoch 85/100
# 7/7 [==============================] - 1s 230ms/step - loss: 0.1229 - accuracy: 0.9559 - val_loss: 0.6617 - val_accuracy: 0.7586
# Epoch 86/100
# 7/7 [==============================] - 1s 211ms/step - loss: 0.1678 - accuracy: 0.9466 - val_loss: 0.6461 - val_accuracy: 0.7931
# Epoch 87/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.1396 - accuracy: 0.9426 - val_loss: 0.6237 - val_accuracy: 0.7931
# Epoch 88/100
# 7/7 [==============================] - 1s 160ms/step - loss: 0.0956 - accuracy: 0.9651 - val_loss: 0.5752 - val_accuracy: 0.8103
# Epoch 89/100
# 7/7 [==============================] - 1s 169ms/step - loss: 0.1101 - accuracy: 0.9477 - val_loss: 0.4658 - val_accuracy: 0.8621
# Epoch 90/100
# 7/7 [==============================] - 1s 171ms/step - loss: 0.1804 - accuracy: 0.9376 - val_loss: 0.5564 - val_accuracy: 0.7759
# Epoch 91/100
# 7/7 [==============================] - 1s 183ms/step - loss: 0.1041 - accuracy: 0.9777 - val_loss: 0.6252 - val_accuracy: 0.7931
# Epoch 92/100
# 7/7 [==============================] - 1s 192ms/step - loss: 0.0637 - accuracy: 0.9810 - val_loss: 0.7006 - val_accuracy: 0.7931
# Epoch 93/100
# 7/7 [==============================] - 1s 169ms/step - loss: 0.0989 - accuracy: 0.9607 - val_loss: 0.6875 - val_accuracy: 0.8103
# Epoch 94/100
# 7/7 [==============================] - 1s 197ms/step - loss: 0.1009 - accuracy: 0.9651 - val_loss: 0.8391 - val_accuracy: 0.7931
# Epoch 95/100
# 7/7 [==============================] - 1s 233ms/step - loss: 0.1089 - accuracy: 0.9638 - val_loss: 0.5796 - val_accuracy: 0.8448
# Epoch 96/100
# 7/7 [==============================] - 1s 188ms/step - loss: 0.0910 - accuracy: 0.9678 - val_loss: 0.6004 - val_accuracy: 0.8276
# Epoch 97/100
# 7/7 [==============================] - 1s 179ms/step - loss: 0.0767 - accuracy: 0.9666 - val_loss: 0.6408 - val_accuracy: 0.8448
# Epoch 98/100
# 7/7 [==============================] - 1s 176ms/step - loss: 0.1144 - accuracy: 0.9758 - val_loss: 0.7899 - val_accuracy: 0.8103
# Epoch 99/100
# 7/7 [==============================] - 1s 175ms/step - loss: 0.0691 - accuracy: 0.9808 - val_loss: 0.7154 - val_accuracy: 0.7931
# Epoch 100/100
# 7/7 [==============================] - 1s 169ms/step - loss: 0.0581 - accuracy: 0.9957 - val_loss: 0.7912 - val_accuracy: 0.8276
# Model Successfully created..
